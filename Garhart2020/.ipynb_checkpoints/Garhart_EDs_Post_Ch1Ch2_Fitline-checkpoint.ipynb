# %%
import numpy as np
import pymc3 as pm
import scipy
from scipy import constants
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from astropy import constants as const
matplotlib.rcParams.update({'font.size': 17,"axes.labelsize": 17})

# %% [markdown]
# # Load the eclipse depth and temperature data from Garhart 2020

# %%
filename='garhart2020.csv'
garhartDF = pd.read_csv(filename)

# %% [markdown]
# Remove the planets that don't have a Ch1 eclipse depth

# %%
garhartDF=garhartDF.drop([18,24])

# %%
#Split the Tb columns into two
garhartDF[['4.5 μm Tb','4.5 μm Tb err']]=garhartDF['4.5 μm Tb'].str.split('±',expand=True).astype('float')
garhartDF[['3.6 μm Tb','3.6 μm Tb err']]=garhartDF['3.6 μm Tb'].str.split('±',expand=True).astype('float')
garhartDF[['T eq','T eq err']] =garhartDF['Equilibrium temperature'].str.split('±',expand=True).astype('float')

# %%
garhartDF
# Out:
#       Planet Equilibrium temperature  3.6 μm Tb  4.5 μm Tb  4.5 μm Tb err  \
# 0     HAT-13                1653± 50     1810.0     1754.0          200.0
# 1     HAT-30                1718± 34     2087.0     1938.0          160.0
# 2     HAT-33               1855± 148     2112.0     1990.0          209.0
# 3     HAT-40                1771± 38     2074.0     1887.0          259.0
# 4     HAT-41                1685± 58     1694.0     1622.0          125.0
# 5     KELT-2                1721± 36     1994.0     1782.0          111.0
# 6     KELT-3                1829± 42     2445.0     2132.0          133.0
# 7     KELT-7                2056± 31     2512.0     2415.0           73.0
# 8    Qatar-1                1422± 36     1410.0     1532.0          219.0
# 9    WASP-12                2546± 82     3329.0     2934.0          114.0
# 10   WASP-14                1893± 60     2302.0     2256.0           92.0
# 11   WASP-14                1893± 60     2292.0     2319.0           92.0
# 12   WASP-18                2416± 58     3057.0     3323.0           80.0
# 13   WASP-19                2099± 39     2451.0     2191.0          169.0
# 14   WASP-19                2099± 39     2465.0     2353.0          219.0
# 15   WASP-36                1705± 44     1336.0     1506.0          420.0
# 16   WASP-43                1444± 40     1781.0     1537.0           78.0
# 17   WASP-46                1663± 54     1435.0     2014.0          267.0
# 19   WASP-62                1432± 33     1955.0     1593.0          153.0
# 20   WASP-63                1536± 37     1547.0     1395.0          324.0
# 21   WASP-64               1674± 169     2135.0     1607.0          366.0
# 22   WASP-65                1490± 45     1833.0     1179.0          518.0
# 23   WASP-74                1922± 46     2049.0     2161.0          105.0
# 25   WASP-76                2190± 43     2669.0     2747.0           60.0
# 26   WASP-77                1677± 28     1786.0     1696.0           87.0
# 27   WASP-78                2200± 41     3034.0     2763.0          483.0
# 28   WASP-79                1760± 51     1959.0     1948.0          117.0
# 29   WASP-87                2320± 62     2802.0     2988.0          152.0
# 30  WASP-94A                1508± 75     1385.0     1249.0          118.0
# 31   WASP-97                1545± 40     1772.0     1615.0          107.0
# 32  WASP-100               2207± 170     2306.0     2429.0          168.0
# 33  WASP-101                1559± 38     1723.0     1524.0          145.0
# 34  WASP-103                2513± 49     2993.0     3268.0          231.0
# 35  WASP-103                2513± 49     2771.0     3066.0          221.0
# 36  WASP-104               1501± 189     1716.0     1783.0          205.0
# 37  WASP-121                2366± 57     2490.0     2562.0           66.0
# 38  WASP-131                1463± 32     1397.0     1114.0          309.0
#
#     3.6 μm Tb err    T eq  T eq err
# 0           229.0  1653.0      50.0
# 1           140.0  1718.0      34.0
# 2           162.0  1855.0     148.0
# 3           354.0  1771.0      38.0
# 4           294.0  1685.0      58.0
# 5           104.0  1721.0      36.0
# 6           133.0  1829.0      42.0
# 7            69.0  2056.0      31.0
# 8           425.0  1422.0      36.0
# 9           172.0  2546.0      82.0
# 10           85.0  1893.0      60.0
# 11           76.0  1893.0      60.0
# 12           63.0  2416.0      58.0
# 13          127.0  2099.0      39.0
# 14          114.0  2099.0      39.0
# 15          844.0  1705.0      44.0
# 16           65.0  1444.0      40.0
# 17          740.0  1663.0      54.0
# 19          177.0  1432.0      33.0
# 20          308.0  1536.0      37.0
# 21          202.0  1674.0     169.0
# 22          284.0  1490.0      45.0
# 23           94.0  1922.0      46.0
# 25           57.0  2190.0      43.0
# 26           84.0  1677.0      28.0
# 27          331.0  2200.0      41.0
# 28          125.0  1760.0      51.0
# 29          172.0  2320.0      62.0
# 30           95.0  1508.0      75.0
# 31          111.0  1545.0      40.0
# 32          180.0  2207.0     170.0
# 33          166.0  1559.0      38.0
# 34          150.0  2513.0      49.0
# 35          181.0  2513.0      49.0
# 36          197.0  1501.0     189.0
# 37           77.0  2366.0      57.0
# 38          369.0  1463.0      32.0

# %% [markdown]
# # Reformat this a bit to make it play nicer with PYMC3
# "Stack" the data so that I can use a single Normal distribution for both channels, and create indices. This makes my life easier when I want to compare the WAIC, LOO, etc. etc. Give a unique index for each planet name, and for the Spitzer IRAC Channel.

# %%
ch2DF=garhartDF[['Planet','4.5 μm Tb','4.5 μm Tb err','T eq','T eq err']].copy()
ch1DF=garhartDF[['Planet','3.6 μm Tb','3.6 μm Tb err','T eq','T eq err']].copy()
ch2DF.columns= ['Planet','Tday','Terr','T eq','T eq err']
ch1DF.columns= ['Planet','Tday','Terr','T eq','T eq err']
ch2DF['Planet Ind']=np.arange(0,37)
ch2DF['Channel']=np.ones(37,dtype=int)*0
ch1DF['Planet Ind']=np.arange(0,37)
ch1DF['Channel']=np.ones(37,dtype=int)*1

# %%
df_cleaned=pd.concat([ch2DF,ch1DF])

# %%
pd.set_option('display.max_rows', 1000)

# %%
df_cleaned
# Out:
#       Planet    Tday   Terr    T eq  T eq err  Planet Ind  Channel
# 0     HAT-13  1754.0  200.0  1653.0      50.0           0        0
# 1     HAT-30  1938.0  160.0  1718.0      34.0           1        0
# 2     HAT-33  1990.0  209.0  1855.0     148.0           2        0
# 3     HAT-40  1887.0  259.0  1771.0      38.0           3        0
# 4     HAT-41  1622.0  125.0  1685.0      58.0           4        0
# 5     KELT-2  1782.0  111.0  1721.0      36.0           5        0
# 6     KELT-3  2132.0  133.0  1829.0      42.0           6        0
# 7     KELT-7  2415.0   73.0  2056.0      31.0           7        0
# 8    Qatar-1  1532.0  219.0  1422.0      36.0           8        0
# 9    WASP-12  2934.0  114.0  2546.0      82.0           9        0
# 10   WASP-14  2256.0   92.0  1893.0      60.0          10        0
# 11   WASP-14  2319.0   92.0  1893.0      60.0          11        0
# 12   WASP-18  3323.0   80.0  2416.0      58.0          12        0
# 13   WASP-19  2191.0  169.0  2099.0      39.0          13        0
# 14   WASP-19  2353.0  219.0  2099.0      39.0          14        0
# 15   WASP-36  1506.0  420.0  1705.0      44.0          15        0
# 16   WASP-43  1537.0   78.0  1444.0      40.0          16        0
# 17   WASP-46  2014.0  267.0  1663.0      54.0          17        0
# 19   WASP-62  1593.0  153.0  1432.0      33.0          18        0
# 20   WASP-63  1395.0  324.0  1536.0      37.0          19        0
# 21   WASP-64  1607.0  366.0  1674.0     169.0          20        0
# 22   WASP-65  1179.0  518.0  1490.0      45.0          21        0
# 23   WASP-74  2161.0  105.0  1922.0      46.0          22        0
# 25   WASP-76  2747.0   60.0  2190.0      43.0          23        0
# 26   WASP-77  1696.0   87.0  1677.0      28.0          24        0
# 27   WASP-78  2763.0  483.0  2200.0      41.0          25        0
# 28   WASP-79  1948.0  117.0  1760.0      51.0          26        0
# 29   WASP-87  2988.0  152.0  2320.0      62.0          27        0
# 30  WASP-94A  1249.0  118.0  1508.0      75.0          28        0
# 31   WASP-97  1615.0  107.0  1545.0      40.0          29        0
# 32  WASP-100  2429.0  168.0  2207.0     170.0          30        0
# 33  WASP-101  1524.0  145.0  1559.0      38.0          31        0
# 34  WASP-103  3268.0  231.0  2513.0      49.0          32        0
# 35  WASP-103  3066.0  221.0  2513.0      49.0          33        0
# 36  WASP-104  1783.0  205.0  1501.0     189.0          34        0
# 37  WASP-121  2562.0   66.0  2366.0      57.0          35        0
# 38  WASP-131  1114.0  309.0  1463.0      32.0          36        0
# 0     HAT-13  1810.0  229.0  1653.0      50.0           0        1
# 1     HAT-30  2087.0  140.0  1718.0      34.0           1        1
# 2     HAT-33  2112.0  162.0  1855.0     148.0           2        1
# 3     HAT-40  2074.0  354.0  1771.0      38.0           3        1
# 4     HAT-41  1694.0  294.0  1685.0      58.0           4        1
# 5     KELT-2  1994.0  104.0  1721.0      36.0           5        1
# 6     KELT-3  2445.0  133.0  1829.0      42.0           6        1
# 7     KELT-7  2512.0   69.0  2056.0      31.0           7        1
# 8    Qatar-1  1410.0  425.0  1422.0      36.0           8        1
# 9    WASP-12  3329.0  172.0  2546.0      82.0           9        1
# 10   WASP-14  2302.0   85.0  1893.0      60.0          10        1
# 11   WASP-14  2292.0   76.0  1893.0      60.0          11        1
# 12   WASP-18  3057.0   63.0  2416.0      58.0          12        1
# 13   WASP-19  2451.0  127.0  2099.0      39.0          13        1
# 14   WASP-19  2465.0  114.0  2099.0      39.0          14        1
# 15   WASP-36  1336.0  844.0  1705.0      44.0          15        1
# 16   WASP-43  1781.0   65.0  1444.0      40.0          16        1
# 17   WASP-46  1435.0  740.0  1663.0      54.0          17        1
# 19   WASP-62  1955.0  177.0  1432.0      33.0          18        1
# 20   WASP-63  1547.0  308.0  1536.0      37.0          19        1
# 21   WASP-64  2135.0  202.0  1674.0     169.0          20        1
# 22   WASP-65  1833.0  284.0  1490.0      45.0          21        1
# 23   WASP-74  2049.0   94.0  1922.0      46.0          22        1
# 25   WASP-76  2669.0   57.0  2190.0      43.0          23        1
# 26   WASP-77  1786.0   84.0  1677.0      28.0          24        1
# 27   WASP-78  3034.0  331.0  2200.0      41.0          25        1
# 28   WASP-79  1959.0  125.0  1760.0      51.0          26        1
# 29   WASP-87  2802.0  172.0  2320.0      62.0          27        1
# 30  WASP-94A  1385.0   95.0  1508.0      75.0          28        1
# 31   WASP-97  1772.0  111.0  1545.0      40.0          29        1
# 32  WASP-100  2306.0  180.0  2207.0     170.0          30        1
# 33  WASP-101  1723.0  166.0  1559.0      38.0          31        1
# 34  WASP-103  2993.0  150.0  2513.0      49.0          32        1
# 35  WASP-103  2771.0  181.0  2513.0      49.0          33        1
# 36  WASP-104  1716.0  197.0  1501.0     189.0          34        1
# 37  WASP-121  2490.0   77.0  2366.0      57.0          35        1
# 38  WASP-131  1397.0  369.0  1463.0      32.0          36        1

# %% [markdown]
# # Scale the dayside temperature by dividing by the irradiation temperature and add this as a new column

# %%
# Scale the temperatures to get m values
df_cleaned['m']=df_cleaned['Tday']/df_cleaned['T eq']*0.25**0.25
df_cleaned['m err']=df_cleaned['Terr']/df_cleaned['T eq']*0.25**0.25

# %%
df_cleaned[0:37]
# Out:
#       Planet    Tday   Terr    T eq  T eq err  Planet Ind  Channel         m  \
# 0     HAT-13  1754.0  200.0  1653.0      50.0           0        0  0.750312
# 1     HAT-30  1938.0  160.0  1718.0      34.0           1        0  0.797656
# 2     HAT-33  1990.0  209.0  1855.0     148.0           2        0  0.758567
# 3     HAT-40  1887.0  259.0  1771.0      38.0           3        0  0.753422
# 4     HAT-41  1622.0  125.0  1685.0      58.0           4        0  0.680669
# 5     KELT-2  1782.0  111.0  1721.0      36.0           5        0  0.732170
# 6     KELT-3  2132.0  133.0  1829.0      42.0           6        0  0.824249
# 7     KELT-7  2415.0   73.0  2056.0      31.0           7        0  0.830575
# 8    Qatar-1  1532.0  219.0  1422.0      36.0           8        0  0.761806
# 9    WASP-12  2934.0  114.0  2546.0      82.0           9        0  0.814867
# 10   WASP-14  2256.0   92.0  1893.0      60.0          10        0  0.842701
# 11   WASP-14  2319.0   92.0  1893.0      60.0          11        0  0.866234
# 12   WASP-18  3323.0   80.0  2416.0      58.0          12        0  0.972565
# 13   WASP-19  2191.0  169.0  2099.0      39.0          13        0  0.738100
# 14   WASP-19  2353.0  219.0  2099.0      39.0          14        0  0.792674
# 15   WASP-36  1506.0  420.0  1705.0      44.0          15        0  0.624576
# 16   WASP-43  1537.0   78.0  1444.0      40.0          16        0  0.752648
# 17   WASP-46  2014.0  267.0  1663.0      54.0          17        0  0.856352
# 19   WASP-62  1593.0  153.0  1432.0      33.0          18        0  0.786607
# 20   WASP-63  1395.0  324.0  1536.0      37.0          19        0  0.642197
# 21   WASP-64  1607.0  366.0  1674.0     169.0          20        0  0.678806
# 22   WASP-65  1179.0  518.0  1490.0      45.0          21        0  0.559516
# 23   WASP-74  2161.0  105.0  1922.0      46.0          22        0  0.795035
# 25   WASP-76  2747.0   60.0  2190.0      43.0          23        0  0.886951
# 26   WASP-77  1696.0   87.0  1677.0      28.0          24        0  0.715118
# 27   WASP-78  2763.0  483.0  2200.0      41.0          25        0  0.888062
# 28   WASP-79  1948.0  117.0  1760.0      51.0          26        0  0.782639
# 29   WASP-87  2988.0  152.0  2320.0      62.0          27        0  0.910705
# 30  WASP-94A  1249.0  118.0  1508.0      75.0          28        0  0.585661
# 31   WASP-97  1615.0  107.0  1545.0      40.0          29        0  0.739144
# 32  WASP-100  2429.0  168.0  2207.0     170.0          30        0  0.778234
# 33  WASP-101  1524.0  145.0  1559.0      38.0          31        0  0.691232
# 34  WASP-103  3268.0  231.0  2513.0      49.0          32        0  0.919548
# 35  WASP-103  3066.0  221.0  2513.0      49.0          33        0  0.862710
# 36  WASP-104  1783.0  205.0  1501.0     189.0          34        0  0.839954
# 37  WASP-121  2562.0   66.0  2366.0      57.0          35        0  0.765684
# 38  WASP-131  1114.0  309.0  1463.0      32.0          36        0  0.538426
#
#        m err
# 0   0.085554
# 1   0.065854
# 2   0.079669
# 3   0.103411
# 4   0.052456
# 5   0.045607
# 6   0.051419
# 7   0.025106
# 8   0.108900
# 9   0.031661
# 10  0.034365
# 11  0.034365
# 12  0.023414
# 13  0.056932
# 14  0.073776
# 15  0.174185
# 16  0.038196
# 17  0.113528
# 19  0.075550
# 20  0.149155
# 21  0.154600
# 22  0.245826
# 23  0.038630
# 25  0.019373
# 26  0.036684
# 27  0.155242
# 28  0.047007
# 29  0.046328
# 30  0.055331
# 31  0.048971
# 32  0.053826
# 33  0.065767
# 34  0.064999
# 35  0.062185
# 36  0.096574
# 37  0.019725
# 38  0.149348

# %%
plt.scatter(df_cleaned[0:37]['T eq'],df_cleaned[0:37]['Tday'],color='red')
plt.scatter(df_cleaned[0:37]['T eq'],df_cleaned[37:37*2]['Tday'],color='blue')

# %%
#plt.scatter(df_cleaned[0:37]['T eq'],df_cleaned[0:37]['Tday'],color='red')
plt.scatter(df_cleaned[0:37]['T eq'],df_cleaned[0:37]['Tday']/df_cleaned[37:37*2]['Tday'],color='blue')

# %% [markdown]
# # The non-hierarchical model

# %%
with pm.Model() as model_sep:
    m_offset = pm.Normal('m offset',0,1,shape=len(df_cleaned.index))
    m = pm.Deterministic('m',0.70+0.175*3*m_offset)
    #Calculate the brightness temp ratio
    #ratio =pm.Deterministic('ratio',m[0:37]/m[37:74])
    
    #Convert m to brightness temp
    #Tday = pm.Deterministic('Tday',m*Teff[2::]*np.sqrt(1/a[2::]))
    #ED= pm.Deterministic('ED',Planck(4.5e-6,Tday)/BStarCh2[2::]*radius[2::]**2)
    y_ = pm.Normal('y',mu=m , sd=df_cleaned['Tday'],observed= df_cleaned['Terr'])

# %% [markdown]
# # Plot predictive posterior check to make sure the priors are giving reasonable values.

# %%
with model_sep:
    ppc_sep =pm.sample_prior_predictive(samples=1000)

# %%
plt.scatter(x=df_cleaned.index,y=np.median(ppc_sep['m'],axis=0),color='red')
plt.scatter(x=df_cleaned.index,y=df_cleaned['m'],color='k')
plt.ylabel(r'$T_{\rm day}/T_{0}$')
plt.xlabel(r'$T_{0}$')
# Out:
# Text(0.5, 0, '$T_{0}$')

# %% [markdown]
# # Fit and sample the separate model. We expect this to just reproduce the published results.

# %%
with model_sep:
    trace_sep =pm.sample(draws=1000,tune=1000,chains=4,cores=4,target_accept=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m offset]
# Sampling 4 chains, 0 divergences: 100%|██████████| 8000/8000 [00:18<00:00, 429.64draws/s]

# %%
summary=pm.summary(trace_sep,var_names=['m'],round_to=7)

# %%
summary
# Out:
#            mean        sd    hdi_3%   hdi_97%  mcse_mean   mcse_sd  \
# m[0]   0.747298  0.081782  0.598684  0.902919   0.000781  0.000559
# m[1]   0.796837  0.065802  0.669677  0.914492   0.000646  0.000462
# m[2]   0.758011  0.078261  0.609836  0.904710   0.000753  0.000532
# m[3]   0.752474  0.103418  0.559033  0.947819   0.001006  0.000748
# m[4]   0.680647  0.051347  0.581946  0.775193   0.000481  0.000344
# m[5]   0.732127  0.045358  0.647772  0.816314   0.000504  0.000361
# m[6]   0.822764  0.049858  0.730362  0.913642   0.000483  0.000343
# m[7]   0.830356  0.024963  0.783798  0.877575   0.000249  0.000177
# m[8]   0.759365  0.109078  0.559867  0.962265   0.001102  0.000782
# m[9]   0.814315  0.031742  0.755820  0.876839   0.000350  0.000247
# m[10]  0.842475  0.035083  0.776335  0.907480   0.000325  0.000233
# m[11]  0.864790  0.034374  0.801188  0.927753   0.000325  0.000230
# m[12]  0.971930  0.024149  0.927500  1.017590   0.000201  0.000142
# m[13]  0.737660  0.057108  0.634038  0.846590   0.000507  0.000362
# m[14]  0.790819  0.072038  0.648221  0.921664   0.000709  0.000516
# m[15]  0.632178  0.166979  0.332150  0.965494   0.001531  0.001278
# m[16]  0.752338  0.037646  0.680797  0.821180   0.000383  0.000273
# m[17]  0.848263  0.109719  0.654012  1.062667   0.001070  0.000784
# m[18]  0.785179  0.074820  0.639998  0.922563   0.000704  0.000506
# m[19]  0.644200  0.141526  0.386218  0.915142   0.001301  0.001033
# m[20]  0.678599  0.150406  0.398992  0.958456   0.001296  0.000963
# m[21]  0.586512  0.220889  0.161667  0.989791   0.002276  0.001913
# m[22]  0.794903  0.038158  0.723717  0.866714   0.000373  0.000269
# m[23]  0.886834  0.019462  0.852960  0.926135   0.000195  0.000139
# m[24]  0.715129  0.037591  0.648002  0.790255   0.000371  0.000265
# ratio[5]    9099.466727   8596.771346   9292.958671  3182.275763  0.999529
# ratio[6]    9459.492592   9192.095912   9431.842756  2674.097079  1.003456
# ratio[7]   10518.050441  10224.857264  10757.119787  2763.499353  1.001063
# ratio[8]    4345.284153   2613.080817  10027.949865  2669.825464  1.001156
# ratio[9]    9701.919336   9701.919336   9031.682186  2469.312614  1.002574
# ratio[10]  11427.151349  11007.471692  11650.570192  2835.057784  1.001242
# ratio[11]  11096.063444  10633.359251  11386.906599  2661.922777  1.000151
# ratio[12]  10873.925273  10692.906501  11034.209376  2949.532046  1.001963
# ratio[13]  11088.395857  10252.494404  11252.291912  2682.433190  1.002108
# ratio[14]  11054.547068  10230.716680  11249.254799  2872.785494  1.000649
# ratio[15]   4017.106062   4016.346268   5606.029484  2794.665231  1.000582
# ratio[16]   9576.384387   9372.564428   9594.472662  2845.052239  1.001215
# ratio[17]   3879.243198   3879.243198   7755.468095  2179.908556  1.000329
# ratio[18]   9972.518744   8628.367072  10479.486785  2951.090132  1.000343
# ratio[19]   7983.045979   5967.502365   9620.732737  2982.474198  1.000805
# ratio[20]  11207.992042   9279.074794  10977.601229  2736.355040  0.999773
# ratio[21]   8483.790358   4822.190249   8793.587952  2582.246503  1.002277
# ratio[22]   9971.451877   9658.100994  10107.609704  2761.775735  0.999347
# ratio[23]  10057.428955   9964.239755  10070.216476  2838.489786  1.004771
# ratio[24]  11325.524384  11325.524384  11413.645669  3240.319283  1.000413
# ratio[25]  10326.633680   8131.813258  11018.198352  2838.199335  1.002157
# ratio[26]  10952.622026  10677.474376  10751.682002  2696.941701  0.999604
# ratio[27]   9757.220876   9327.802837   9903.292707  3171.124619  1.000284
# ratio[28]   8461.624369   7949.387222   8554.918059  3019.012158  1.001377
# ratio[29]   8916.478098   8482.166021   8986.669681  2448.217788  1.001254
# ratio[30]   9662.475975   8699.971288  10274.048361  3098.010485  1.000683
# ratio[31]   9784.522134   8305.701312  10527.042737  2688.885428  1.000777
# ratio[32]   9298.830922   9077.245241   9360.286985  2724.672126  1.000237
# ratio[33]   9649.665928   9010.006624   9585.599209  3167.121131  1.000795
# ratio[34]   9172.736000   7260.536413  10462.999195  2864.137786  1.001424
# ratio[35]  12100.054263  11839.938225  12185.322767  2624.760686  1.000926
# ratio[36]   4212.533517   2856.069597  10173.500285  2443.801517  1.000989

# %%
plt.scatter(df_cleaned['T eq'][0:37],summary_ratio['mean'])
plt.errorbar(x=df_cleaned['T eq'][0:37],y=summary_ratio['mean'],yerr=summary_ratio['sd'],linestyle='None')
plt.ylim(0.4,1.7)
plt.ylabel(r'$T_{\rm Ch 2}/T_{\rm Ch 1}$')
plt.xlabel(r'$T_{0}$')
# Out:
# Text(0.5, 0, '$T_{0}$')

# %% [markdown]
# # The hierarchical models

# %% [markdown]
# The first model will be a wavelength independent hierarchical model--- a common hierarchical distribution for both channels.

# %%
Tdaymean = np.array((df_cleaned[0:37]['Tday'].mean(),df_cleaned[37:37*2]['Tday'].mean()))
Teqmean =df_cleaned[0:37]['T eq'].mean()
Tdaymean, Teqmean
# Out:
# (array([2058.7027027 , 2132.64864865]), 1860.6486486486488)

# %%
with pm.Model() as model_hier_ind:
    m_hier_offset = pm.Normal('m hier offset',0,1)
    m_hier = pm.Deterministic('m hier',1+0.175*3*m_hier_offset)
    
    b_offset = pm.Normal('b offset',0,1)
    b = pm.Deterministic('b',2200+500*b_offset)
    
    m_sig = pm.HalfNormal('m sig',500)
    
    m_offset = pm.Normal('m offset',0,1,shape=len(df_cleaned.index))
    m = pm.Deterministic('m',m_hier*(df_cleaned['T eq']-Teqmean)+b+m_sig*m_offset)

    #Calculate the brightness temp ratio
    #ratio =pm.Deterministic('ratio',m[0:37]/m[37:74])
    #Convert m to brightness temp
    #Tday = pm.Deterministic('Tday',m*Teff[2::]*np.sqrt(1/a[2::]))
    #ED= pm.Deterministic('ED',Planck(4.5e-6,Tday)/BStarCh2[2::]*radius[2::]**2)
    y_= pm.Normal('Tday',mu=m , sd=df_cleaned['Terr'],observed= df_cleaned['Tday'])

# %% [markdown]
# # First do a prior predictive check.

# %%
with model_hier_ind:
    ppc_hier_ind =pm.sample_prior_predictive(samples=1000)

# %%
plt.scatter(x=df_cleaned['T eq'],y=np.median(ppc_hier_ind['Tday'],axis=0),color='red')
plt.scatter(x=df_cleaned['T eq'],y=df_cleaned['Tday'],color='k')
plt.ylabel(r'$T_{\rm day}/T_{0}$')
plt.xlabel(r'$T_{0}$')
# Out:
# Text(0.5, 0, '$T_{0}$')

# %%
with model_hier_ind:
    trace_hier_ind =pm.sample(draws=1000,tune=1000,chains=4,cores=4,target_accept=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m offset, m sig, b offset, m hier offset]
# Sampling 4 chains, 0 divergences: 100%|██████████| 8000/8000 [00:27<00:00, 290.20draws/s]

# %%
pm.summary(trace_hier_ind)
# Out:
#                    mean       sd    hdi_3%   hdi_97%  mcse_mean  mcse_sd  \
# m hier offset     0.808    0.141     0.530     1.061      0.004    0.003
# b offset         -0.153    0.052    -0.246    -0.056      0.001    0.001
# m offset[0]      -0.180    0.826    -1.818     1.274      0.011    0.016
# m offset[1]       0.065    0.745    -1.380     1.392      0.010    0.012
# m offset[2]      -0.290    0.826    -1.852     1.275      0.011    0.012
# m offset[3]      -0.176    0.883    -1.881     1.488      0.012    0.015
# m offset[4]      -0.973    0.650    -2.266     0.134      0.009    0.007
# m offset[5]      -0.623    0.620    -1.785     0.574      0.010    0.008
# m offset[6]       0.198    0.705    -1.079     1.581      0.009    0.011
# m offset[7]       0.073    0.471    -0.755     0.990      0.007    0.007
# m offset[8]       0.068    0.835    -1.396     1.741      0.010    0.014
# m offset[9]      -0.696    0.656    -1.912     0.570      0.011    0.009
# m offset[10]      0.411    0.526    -0.551     1.398      0.007    0.007
# m offset[11]      0.720    0.572    -0.402     1.764      0.008    0.007
# m offset[12]      2.134    0.567     1.093     3.191      0.011    0.008
# m offset[13]     -0.773    0.760    -2.217     0.666      0.010    0.009
# m offset[14]     -0.227    0.827    -1.719     1.363      0.011    0.013
# m offset[15]     -0.308    0.950    -2.073     1.437      0.013    0.016
# m offset[16]      0.028    0.532    -0.960     1.049      0.009    0.008
# m offset[17]      0.281    0.881    -1.300     2.051      0.011    0.013
# m offset[18]      0.265    0.734    -1.117     1.590      0.010    0.012
# m offset[19]     -0.296    0.925    -1.945     1.507      0.010    0.014
# m offset[20]     -0.230    0.912    -1.868     1.558      0.012    0.016
# m offset[21]     -0.233    0.944    -1.973     1.580      0.013    0.014
# m offset[22]     -0.231    0.596    -1.364     0.901      0.009    0.009
# m offset[23]      0.906    0.423     0.069     1.678      0.007    0.005
# m offset[24]     -0.842    0.550    -1.933     0.129      0.008    0.007
# m offset[25]      0.073    0.968    -1.741     1.869      0.013    0.016
# m offset[26]     -0.142    0.640    -1.287     1.096      0.009    0.010
# m offset[27]      0.675    0.757    -0.804     2.025      0.011    0.010
# m[38]            6523.0  6523.0    6524.0    3231.0    1.0
# m[39]            6358.0  6283.0    6349.0    3267.0    1.0
# m[40]            6088.0  6088.0    6091.0    2936.0    1.0
# m[41]            4764.0  4764.0    4775.0    3015.0    1.0
# m[42]            5397.0  5397.0    5403.0    2839.0    1.0
# m[43]            6365.0  6365.0    6329.0    2818.0    1.0
# m[44]            7787.0  7787.0    7748.0    2674.0    1.0
# m[45]            4615.0  4581.0    4582.0    3072.0    1.0
# m[46]            6333.0  6283.0    6379.0    3208.0    1.0
# m[47]            6025.0  6010.0    6014.0    3072.0    1.0
# m[48]            6760.0  6760.0    6782.0    3056.0    1.0
# m[49]            7083.0  7083.0    7119.0    3004.0    1.0
# m[50]            6674.0  6642.0    6624.0    3103.0    1.0
# m[51]            5735.0  5735.0    5744.0    3220.0    1.0
# m[52]            5672.0  5541.0    5621.0    2967.0    1.0
# m[53]            7067.0  7038.0    7074.0    3310.0    1.0
# m[54]            4962.0  4957.0    4966.0    2784.0    1.0
# m[55]            4947.0  4913.0    4944.0    3121.0    1.0
# m[56]            6414.0  6263.0    6403.0    3265.0    1.0
# m[57]            6311.0  6212.0    6336.0    2993.0    1.0
# m[58]            5831.0  5686.0    5853.0    2841.0    1.0
# m[59]            6262.0  6262.0    6311.0    3366.0    1.0
# m[60]            6282.0  6282.0    6333.0    3210.0    1.0
# m[61]            7037.0  6952.0    7096.0    3175.0    1.0
# m[62]            5008.0  5003.0    5005.0    2876.0    1.0
# m[63]            7368.0  7324.0    7327.0    2815.0    1.0
# m[64]            6446.0  6426.0    6524.0    3346.0    1.0
# m[65]            7881.0  7798.0    7880.0    3110.0    1.0
# m[66]            8839.0  8839.0    8806.0    3038.0    1.0
# m[67]            5314.0  5304.0    5271.0    2851.0    1.0
# m[68]            5429.0  5429.0    5435.0    2918.0    1.0
# m[69]            5477.0  5477.0    5308.0    3275.0    1.0
# m[70]            5266.0  5266.0    5262.0    3162.0    1.0
# m[71]            6745.0  6650.0    6740.0    2863.0    1.0
# m[72]            6098.0  6088.0    6137.0    3193.0    1.0
# m[73]            5388.0  5219.0    5357.0    2644.0    1.0

# %%
summary_hier_ind=pm.summary(trace_hier_ind,var_names=['m'],round_to=7)
#summary_ratio_ind=pm.summary(trace_hier_ind,var_names=['ratio'],round_to=7)

# %% [markdown]
# # Plot the brightness temperature ratio for each planet.

# %%
# plt.scatter(df_cleaned['T eq'][0:37],summary_ratio_ind['mean'],color='k')
# plt.errorbar(x=df_cleaned['T eq'][0:37],y=summary_ratio_ind['mean'],yerr=summary_ratio_ind['sd'],linestyle='None',color='k')
# plt.ylabel(r'$T_{\rm Ch 2}/T_{\rm Ch 1}$')
# plt.xlabel(r'$T_{0}$')

# %%
pm.summary(trace_hier_ind,var_names=['m hier','m sig','b'],round_to=7)
# Out:
#                mean         sd       hdi_3%      hdi_97%  mcse_mean   mcse_sd  \
# m hier     1.424273   0.073853     1.278002     1.556814   0.001916  0.001355
# m sig    148.547281  21.174363   108.435622   187.632127   0.532114  0.376719
# b       2123.322059  25.885827  2077.144111  2171.856232   0.635840  0.449836
#
#            ess_mean       ess_sd     ess_bulk     ess_tail     r_hat
# m hier  1485.405758  1485.405758  1491.373360  2195.740893  1.003032
# m sig   1583.477312  1580.217627  1603.605886  2421.039381  1.004876
# b       1657.404001  1656.295310  1653.734960  2325.531342  1.002212

# %%
plt.figure(figsize=(8,8))
matplotlib.rcParams.update({'font.size': 18,"axes.labelsize": 20})

plt.errorbar(x=df_cleaned['T eq']/(0.25**0.25),y=summary_hier_ind['mean'],yerr=summary_hier_ind['sd'],linestyle='None',color='k')
plt.scatter(x=df_cleaned['T eq']/(0.25**0.25),y=summary_hier_ind['mean'],color='k',s=60,label='Hierarchical')
plt.errorbar(x=df_cleaned['T eq']/(0.25**0.25),y=df_cleaned['Tday'],yerr=df_cleaned['Terr'],linestyle='None',color='maroon',alpha=0.5)
plt.scatter(x=df_cleaned['T eq']/(0.25**0.25),y=df_cleaned['Tday'],color='maroon',s=60,alpha=0.5,label='Separate')
#plt.axhline((2/3)**0.25,color='gray')
#plt.axhline(0.5**0.25,color='gray',linestyle='dashed')
#plt.axhline(0.25**0.25,color='gray',linestyle='dotted')
plt.ylabel(r'$T_{\rm day}/T_{0}$')
plt.xlabel(r'$T_{0}$')
#plt.ylim(0.18,1.1)
plt.legend(loc=4)
#plt.savefig('Garhart_Hier_2channel.pdf',bbox_inches='tight')

# %%
T0 =df_cleaned['T eq']/(0.25**0.25)

# %%
summary_hier_ind['mean']/T0.values
# Out:
# m[0]     0.770265
# m[1]     0.794162
# m[2]     0.789845
# m[3]     0.786344
# m[4]     0.725652
# m[5]     0.753035
# m[6]     0.814763
# m[7]     0.829620
# m[8]     0.750418
# m[9]     0.832265
# m[10]    0.833030
# m[11]    0.849904
# m[12]    0.944747
# m[13]    0.790872
# m[14]    0.818205
# m[15]    0.769419
# m[16]    0.751268
# m[17]    0.801243
# m[18]    0.766425
# m[19]    0.744150
# m[20]    0.770069
# m[21]    0.740471
# m[22]    0.800893
# m[23]    0.879961
# m[24]    0.732798
# m[25]    0.841410
# m[26]    0.787035
# m[27]    0.877271
# m[28]    0.654504
# m[29]    0.748486
# m[30]    0.812519
# m[31]    0.728807
# m[32]    0.876790
# m[33]    0.859666
# m[34]    0.787352
# m[35]    0.780307
# m[36]    0.712264
# m[37]    0.779567
# m[38]    0.826050
# m[39]    0.805199
# m[40]    0.800800
# m[41]    0.769589
# m[42]    0.809063
# m[43]    0.881001
# m[44]    0.856902
# m[45]    0.739567
# m[46]    0.888086
# m[47]    0.846868
# m[48]    0.846794
# m[49]    0.887862
# m[50]    0.827233
# m[51]    0.829666
# m[52]    0.782649
# m[53]    0.851528
# m[54]    0.775546
# m[55]    0.836958
# m[56]    0.755036
# m[57]    0.825479
# m[58]    0.780441
# m[59]    0.771102
# m[60]    0.858110
# m[61]    0.761204
# m[62]    0.860369
# m[63]    0.791521
# m[64]    0.849847
# m[65]    0.683093
# m[66]    0.794053
# m[67]    0.798433
# m[68]    0.773782
# m[69]    0.850857
# m[70]    0.827115
# m[71]    0.776374
# m[72]    0.767404
# m[73]    0.742148
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(8,8))
matplotlib.rcParams.update({'font.size': 18,"axes.labelsize": 20})

plt.errorbar(x=T0,y=summary_hier_ind['mean']/T0.values,yerr=summary_hier_ind['sd']/T0.values,linestyle='None',color='k')
plt.scatter(x=T0,y=summary_hier_ind['mean']/T0.values,color='k',s=60,label='Hierarchical')
plt.errorbar(x=T0,y=df_cleaned['m'],yerr=df_cleaned['m err'],linestyle='None',color='maroon',alpha=0.5)
plt.scatter(x=T0,y=df_cleaned['m'],color='maroon',s=60,alpha=0.5,label='Separate')
#plt.axhline((2/3)**0.25,color='gray')
#plt.axhline(0.5**0.25,color='gray',linestyle='dashed')
#plt.axhline(0.25**0.25,color='gray',linestyle='dotted')
plt.ylabel(r'$T_{\rm day}/T_{0}$')
plt.xlabel(r'$T_{0}$')
#plt.ylim(0.18,1.1)
plt.legend(loc=4)
#plt.savefig('Garhart_Hier_2channel.pdf',bbox_inches='tight')

# %%
pm.traceplot(trace_hier_ind)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13526d640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1351cdf70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1352eb340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13517b9d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1353675b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1353908b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1353ba4f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1353e4c40>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x135413400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1354407c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13546ee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13549ba60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1354ce2e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1354fe640>]],
#       dtype=object)

# %%
with pm.Model() as model_hier_ind_sep:
    m_hier_offset = pm.Normal('m hier offset',0,1,shape=2)
    m_hier = pm.Deterministic('m hier',1+0.175*3*m_hier_offset)
    
    b_offset = pm.Normal('b offset',0,1,shape=2)
    b = pm.Deterministic('b',2200+500*b_offset)
    
    m_sig = pm.HalfNormal('m sig',500)
    
    m_offset = pm.Normal('m offset',0,1,shape=len(df_cleaned.index))
    m = pm.Deterministic('m',m_hier[df_cleaned['Channel']]*(df_cleaned['T eq']-Teqmean)
                         +b[df_cleaned['Channel']]+m_sig*m_offset)

    #Calculate the brightness temp ratio
    #ratio =pm.Deterministic('ratio',m[0:37]/m[37:74])
    #Convert m to brightness temp
    #Tday = pm.Deterministic('Tday',m*Teff[2::]*np.sqrt(1/a[2::]))
    #ED= pm.Deterministic('ED',Planck(4.5e-6,Tday)/BStarCh2[2::]*radius[2::]**2)
    y_= pm.Normal('Tday',mu=m , sd=df_cleaned['Terr'],observed= df_cleaned['Tday'])
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
with model_hier_ind_sep:
    trace_hier_ind_sep =pm.sample(draws=1000,tune=1000,chains=4,cores=4,target_accept=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m offset, m sig, b offset, m hier offset]
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sampling 4 chains, 0 divergences: 100%|██████████| 8000/8000 [00:46<00:00, 170.97draws/s]
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
pm.compare({'sep':trace_hier_ind_sep,'intercept':trace_hier_ind},ic='waic')
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:150: UserWarning:
# The scale is now log by default. Use 'scale' argument or 'stats.ic_scale' rcParam if you rely on a specific value.
# A higher log-score (or a lower deviance) indicates a model with better predictive accuracy.
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:1409: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
#           rank     waic   p_waic   d_waic    weight       se      dse warning  \
# sep          0 -489.354  22.7252        0  0.731512  4.34794        0    True
# intercept    1  -490.68  23.4256  1.32535  0.268488  4.67139  1.49082    True
#
#           waic_scale
# sep              log
# intercept        log

# %%
pm.summary(trace_hier_ind_sep,varnames=['m hier','b'])
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/pymc3/stats/__init__.py:19: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.9
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#                mean      sd    hdi_3%   hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# m hier[0]     1.549   0.101     1.367     1.745      0.002    0.002    1635.0
# m hier[1]     1.279   0.100     1.084     1.463      0.002    0.002    1655.0
# b[0]       2080.803  35.291  2014.561  2147.921      0.852    0.603    1715.0
# b[1]       2166.131  34.207  2103.402  2231.221      0.902    0.638    1439.0
#
#            ess_sd  ess_bulk  ess_tail  r_hat
# m hier[0]  1635.0    1657.0    2574.0    1.0
# m hier[1]  1651.0    1660.0    2417.0    1.0
# b[0]       1714.0    1715.0    2390.0    1.0
# b[1]       1439.0    1440.0    2304.0    1.0

# %%
m_fit = []
garhart_tday = []
garhart_m = []
tdayfit =[]
tirr = []
channel =df_cleaned['Channel']
planet = []
for ind,obs in enumerate(summary_hier_ind['mean']):
    #print(df_cleaned['Planet'].values[ind],obs,summary_hier['sd'][ind])
    planet.append(str(df_cleaned['Planet'].values[ind])+' b')
    tirr.append(str(int((df_cleaned['T eq'].values[ind]/0.25**0.25).round(0)))+'$\pm$'+str(int((df_cleaned['T eq err'].values[ind]/0.25**0.25).round(0))))
    m_fit.append(str(summary_hier_ind['mean'][ind].round(2))+'$\pm$'+str(summary_hier_ind['sd'][ind].round(2)))
    garhart_tday.append(str(int(df_cleaned['Tday'].round(0).values[ind]))+'$\pm'+str(int(df_cleaned['Terr'].round(0).values[ind])))
    tdayfit.append(str(int((summary_hier_ind['mean'][ind]*df_cleaned['T eq'].values[ind]/0.25**0.25).round(0)))+
                  '$\pm$'+str(int((summary_hier_ind['sd'][ind]*df_cleaned['T eq'].values[ind]/0.25**0.25).round(0))))
    garhart_m.append(str((df_cleaned['m'].round(2).values[ind]))+'$\pm'+str(df_cleaned['m err'].round(2).values[ind]))

# %%
channel=np.zeros(len(tdayfit))
channel[0:37] = 2
channel[37:74]=1

# %%
d = {'Planet':planet,'$T_{0}$':tirr,'Channel':channel.astype(int),
     'Tday':tdayfit,'m':m_fit}

# %%
result =pd.DataFrame(d)
result.to_csv('Garhart_2020_Results.csv',index=False)

# %% [markdown]
# # Now sample the wavelength dependent model.

# %%
with pm.Model() as model_hier_sep:
    m_hier_offset = pm.Normal('m hier offset',0,1,shape=2)
    m_hier = pm.Deterministic('m hier',0.7+0.175*3*m_hier_offset)
    
    m_sig = pm.HalfNormal('m sig',0.5,shape=2)
    
    m_offset = pm.Normal('m offset',0,1,shape=len(df_cleaned.index))
    m = pm.Deterministic('m',m_hier[df_cleaned['Channel']]+m_sig[df_cleaned['Channel']]*m_offset)

    #Convert m to brightness temp
    #Tday = pm.Deterministic('Tday',m*Teff[2::]*np.sqrt(1/a[2::]))
    #ED= pm.Deterministic('ED',Planck(4.5e-6,Tday)/BStarCh2[2::]*radius[2::]**2)
    y_= pm.Normal('y ch2',mu=m , sd=df_cleaned['m err'],observed= df_cleaned['m'])
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
with model_hier_sep:
    trace_hier_sep =pm.sample(draws=1000,tune=2000,chains=4,cores=4,target_accept=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m offset, m sig, m hier offset]
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sampling 4 chains, 0 divergences: 100%|██████████| 12000/12000 [00:40<00:00, 293.37draws/s]
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %% [markdown]
# # Compute the WAIC values for the three models and compare.

# %%
pm.compare({'Wavelength Independent':trace_hier_ind,'Wavelength Dependent':trace_hier_sep,'sep':trace_sep},ic='waic')
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:150: UserWarning:
# The scale is now log by default. Use 'scale' argument or 'stats.ic_scale' rcParam if you rely on a specific value.
# A higher log-score (or a lower deviance) indicates a model with better predictive accuracy.
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:1409: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
#                        rank     waic   p_waic    d_waic     weight       se  \
# Wavelength Dependent      0  88.1586  25.1339         0   0.564687  5.77375
# Wavelength Independent    1  87.7222  24.9906  0.436354   0.424472  5.76157
# sep                       2  78.0033  34.7435   10.1553  0.0108407  5.33953
#
#                             dse warning waic_scale
# Wavelength Dependent          0    True        log
# Wavelength Independent  1.92412    True        log
# sep                     4.21011    True        log

# %%
pm.summary(trace_hier_sep,var_names=['m hier','m sig'],round_to=7)
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#                mean        sd    hdi_3%   hdi_97%  mcse_mean   mcse_sd  \
# m hier[0]  0.790606  0.016155  0.760337  0.821248   0.000487  0.000344
# m hier[1]  0.824928  0.013183  0.799303  0.849072   0.000364  0.000257
# m sig[0]   0.073005  0.013614  0.047673  0.097566   0.000356  0.000252
# m sig[1]   0.053088  0.012233  0.031610  0.076717   0.000337  0.000239
#
#               ess_mean       ess_sd     ess_bulk     ess_tail     r_hat
# m hier[0]  1101.861978  1101.640786  1103.486246  1909.905176  1.001521
# m hier[1]  1313.557633  1313.557633  1311.325003  2140.323027  1.004608
# m sig[0]   1463.785848  1463.785848  1477.634380  2143.639578  0.999880
# m sig[1]   1315.169892  1313.400492  1345.675225  1878.573506  1.001074

# %% [markdown]
# # Let's try a model where we fit a line as a function of T eq.

# %%
with pm.Model() as model_hier_sep_line:
    m_hier_offset = pm.Normal('m hier offset',0,1,shape=2)
    m_hier = pm.Deterministic('m hier',0.7+0.175*3*m_hier_offset)
    
    m_sig = pm.HalfNormal('m sig',0.5,shape=2)
    a_offset = pm.Normal('a offset',0,1)
    a = pm.Deterministic('a',200*10**-6*a_offset)
    m_offset = pm.Normal('m offset',0,1,shape=len(df_cleaned.index))
    m = pm.Deterministic('m',m_hier[df_cleaned['Channel']]+m_sig[df_cleaned['Channel']]*m_offset)

    #Convert m to brightness temp
    #Tday = pm.Deterministic('Tday',m*Teff[2::]*np.sqrt(1/a[2::]))
    #ED= pm.Deterministic('ED',Planck(4.5e-6,Tday)/BStarCh2[2::]*radius[2::]**2)
    y_= pm.Normal('y ch2',mu=m+a*df_cleaned['T eq'] , sd=df_cleaned['m err'],observed= df_cleaned['m'])
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
with model_hier_sep_line:
    trace_hier_line =pm.sample(draws=1000,tune=2000,chains=4,cores=4,target_accept=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m offset, a offset, m sig, m hier offset]
# Sampling 4 chains, 0 divergences: 100%|██████████| 12000/12000 [02:16<00:00, 87.80draws/s]
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
pm.traceplot(trace_hier_line)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13b07e280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c9f1fa0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13c9d5730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x140369e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13ca04c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1403b52b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1403e27f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142eb1e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x142edba60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143dc0280>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x143dec640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1446c39d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1446f0d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144724100>]],
#       dtype=object)

# %%
pm.compare({'Wavelength Independent':trace_hier_ind,'Wavelength Dependent':trace_hier_sep,'Line':trace_hier_line,'sep':trace_sep},ic='waic')
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:150: UserWarning:
# The scale is now log by default. Use 'scale' argument or 'stats.ic_scale' rcParam if you rely on a specific value.
# A higher log-score (or a lower deviance) indicates a model with better predictive accuracy.
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:1409: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#                        rank     waic   p_waic   d_waic      weight       se  \
# Line                      0  91.7057  22.7026        0    0.849806  5.84327
# Wavelength Dependent      1  88.1586  25.1339  3.54716   0.0855247   5.8775
# Wavelength Independent    2  87.7222  24.9906  3.98351   0.0628593  5.28172
# sep                       3  78.0033  34.7435  13.7024  0.00181012  5.13178
#
#                             dse warning waic_scale
# Line                          0    True        log
# Wavelength Dependent    2.47498    True        log
# Wavelength Independent  2.40652    True        log
# sep                     3.70215    True        log

# %% [markdown]
# # Let's try fitting two separate slopes (wavelength dependent) and compare the slope ratios.

# %%
with pm.Model() as model_hier_sep_ratio:
    m_hier_offset = pm.Normal('m hier offset',0,1,shape=2)
    m_hier = pm.Deterministic('m hier',0.7+0.175*3*m_hier_offset)
    
    m_sig = pm.HalfNormal('m sig',0.5,shape=2)
    
    a_offset = pm.Normal('a offset',0,1,shape =2)
    a = pm.Deterministic('a',200*10**-6*a_offset)
    slopediff = pm.Deterministic('a difference',a[0]-a[1])
    m_offset = pm.Normal('m offset',0,1,shape=len(df_cleaned.index))
    m = pm.Deterministic('m',m_hier[df_cleaned['Channel']]+m_sig[df_cleaned['Channel']]*m_offset)

    #Convert m to brightness temp
    #Tday = pm.Deterministic('Tday',m*Teff[2::]*np.sqrt(1/a[2::]))
    #ED= pm.Deterministic('ED',Planck(4.5e-6,Tday)/BStarCh2[2::]*radius[2::]**2)
    y_= pm.Normal('y ch2',mu=m+a[df_cleaned['Channel']]*df_cleaned['T eq'] , sd=df_cleaned['m err'],observed= df_cleaned['m'])
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
with model_hier_sep_ratio:
    trace_hier_ratio =pm.sample(draws=1000,tune=2000,chains=4,cores=4,target_accept=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m offset, a offset, m sig, m hier offset]
# Sampling 4 chains, 0 divergences: 100%|██████████| 12000/12000 [03:33<00:00, 56.20draws/s]
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])

# %%
pm.summary(trace_hier_ratio,round_to=7)
# Out:
#                       mean        sd    hdi_3%   hdi_97%  mcse_mean  \
# m hier offset[0] -0.381225  0.143774 -0.659745 -0.115236   0.004383
# m hier offset[1]  0.077300  0.141304 -0.196873  0.330686   0.003935
# a offset[0]       0.759233  0.191175  0.391628  1.104031   0.005940
# a offset[1]       0.215225  0.187042 -0.142492  0.550641   0.005315
# m offset[0]      -0.003315  0.845174 -1.604425  1.549757   0.012678
# m offset[1]       0.261434  0.795451 -1.167886  1.792996   0.013178
# m offset[2]      -0.146622  0.820106 -1.727480  1.328128   0.012830
# m offset[3]      -0.053440  0.888148 -1.767594  1.638387   0.013642
# m offset[4]      -0.701195  0.702461 -1.998851  0.626412   0.011588
# m offset[5]      -0.306759  0.677911 -1.623027  0.936029   0.011564
# m offset[6]       0.442273  0.723649 -0.910509  1.796639   0.012506
# m offset[7]       0.273091  0.496192 -0.647605  1.238609   0.008865
# m offset[8]       0.159628  0.886879 -1.471904  1.858869   0.013961
# m offset[9]      -0.989322  0.656158 -2.255038  0.202178   0.014435
# m offset[10]      0.746603  0.583848 -0.314456  1.903567   0.009885
# m offset[11]      1.038592  0.589611 -0.036817  2.178216   0.010356
# m offset[12]      1.684163  0.569683  0.697500  2.828926   0.012769
# m offset[13]     -0.702607  0.737954 -2.122316  0.647020   0.012245
# m offset[14]     -0.178677  0.819314 -1.687633  1.409634   0.012971
# m offset[15]     -0.216207  0.969266 -1.954068  1.669398   0.015477
# m offset[16]      0.411974  0.662816 -0.805283  1.662644   0.012887
# m offset[17]      0.374787  0.919753 -1.287513  2.098203   0.014632
# m[60]             1581.899058  1.004639
# m[61]             1755.490182  1.003835
# m[62]             2071.305396  1.003060
# m[63]             2025.710088  1.003710
# m[64]             1895.769637  1.004024
# m[65]             2155.075935  1.002538
# m[66]             2337.522630  1.003512
# m[67]             2088.062092  1.005152
# m[68]             2268.809135  1.003206
# m[69]             1670.959039  1.004540
# m[70]             1687.463068  1.004316
# m[71]             2125.959012  1.004656
# m[72]             1607.889065  1.004404
# m[73]             2366.179465  1.004177

# %%
pm.compare({'Wavelength Independent':trace_hier_ind,'Wavelength Dependent':trace_hier_sep,'Ratio':trace_hier_ratio,'sep':trace_sep},ic='waic')
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:150: UserWarning:
# The scale is now log by default. Use 'scale' argument or 'stats.ic_scale' rcParam if you rely on a specific value.
# A higher log-score (or a lower deviance) indicates a model with better predictive accuracy.
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:1409: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#                        rank     waic   p_waic   d_waic      weight       se  \
# Ratio                     0  92.4006  22.3532        0    0.892026  5.93739
# Wavelength Dependent      1  88.1586  25.1339  4.24202   0.0455945  5.72922
# Wavelength Independent    2  87.7222  24.9906  4.67837   0.0606844  5.05976
# sep                       3  78.0033  34.7435  14.3973  0.00169515  5.33246
#
#                             dse warning waic_scale
# Ratio                         0    True        log
# Wavelength Dependent    1.86904    True        log
# Wavelength Independent  2.66783    True        log
# sep                     3.70832    True        log

# %%
trace_hier_ratio['a'].shape
# Out:
# (4000, 2)

# %%
plt.scatter(x=df_cleaned['T eq'][0:37],y=np.median(trace_hier_ratio['m'],axis=0)[0:37]+df_cleaned['T eq'][0:37]*np.median(trace_hier_ratio['a'],axis=0)[0],color='red')
plt.plot(df_cleaned['T eq'][0:37],df_cleaned['T eq'][0:37]*np.median(trace_hier_ratio['a'],axis=0)[0]+
        np.median(trace_hier_ratio['m hier'],axis=0)[0],color='red')
plt.scatter(df_cleaned['T eq'][0:37],df_cleaned['m'][0:37],color='k')

# %%
plt.scatter(x=df_cleaned['T eq'][37:37*2],y=np.median(trace_hier_ratio['m'],axis=0)[37:37*2]+df_cleaned['T eq'][37:37*2]*np.median(trace_hier_ratio['a'],axis=0)[1],color='red')
plt.plot(df_cleaned['T eq'][37:37*2],df_cleaned['T eq'][37:37*2]*np.median(trace_hier_ratio['a'],axis=0)[1]+
        np.median(trace_hier_ratio['m hier'],axis=0)[1],color='red')
plt.scatter(df_cleaned['T eq'][37:37*2],df_cleaned['m'][37:37*2],color='k')

# %%
plt.scatter(x=df_cleaned['T eq'][0:37],y=np.median(trace_hier_ratio['m'],axis=0)[0:37]+df_cleaned['T eq'][0:37]*np.median(trace_hier_ratio['a'],axis=0)[0],color='red')
plt.plot(df_cleaned['T eq'][0:37],df_cleaned['T eq'][0:37]*np.median(trace_hier_ratio['a'],axis=0)[0]+
        np.median(trace_hier_ratio['m hier'],axis=0)[0],color='red')
plt.scatter(df_cleaned['T eq'][0:37],df_cleaned['m'][0:37],color='k')

plt.scatter(x=df_cleaned['T eq'][37:37*2],y=np.median(trace_hier_ratio['m'],axis=0)[37:37*2]+df_cleaned['T eq'][37:37*2]*np.median(trace_hier_ratio['a'],axis=0)[1],color='purple')
plt.plot(df_cleaned['T eq'][37:37*2],df_cleaned['T eq'][37:37*2]*np.median(trace_hier_ratio['a'],axis=0)[1]+
        np.median(trace_hier_ratio['m hier'],axis=0)[1],color='purple')
plt.scatter(df_cleaned['T eq'][37:37*2],df_cleaned['m'][37:37*2],color='k')

# %%
pm.compare({'Wavelength Independent':trace_hier_ind,'Wavelength Dependent':trace_hier_sep,'Line':trace_hier_ratio,'sep':trace_sep},ic='waic')
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:150: UserWarning:
# The scale is now log by default. Use 'scale' argument or 'stats.ic_scale' rcParam if you rely on a specific value.
# A higher log-score (or a lower deviance) indicates a model with better predictive accuracy.
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/arviz/stats/stats.py:1409: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#                        rank     waic   p_waic   d_waic      weight       se  \
# Line                      0  92.4006  22.3532        0    0.899862  5.78706
# Wavelength Dependent      1  88.1586  25.1339  4.24202   0.0374056     5.66
# Wavelength Independent    2  87.7222  24.9906  4.67837   0.0604989  5.09684
# sep                       3  78.0033  34.7435  14.3973  0.00223324  5.29053
#
#                             dse warning waic_scale
# Line                          0    True        log
# Wavelength Dependent    1.86904    True        log
# Wavelength Independent  2.66783    True        log
# sep                     3.70832    True        log

# %%
pm.summary(trace_hier_ratio,varnames=['a','a ratio','m hier','m sig'],round_to=7)
# Out:
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/pymc3/stats/__init__.py:19: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.9
#   warnings.warn(
# /Users/dylanskeating/opt/miniconda3/envs/pymc3/lib/python3.8/site-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
#                mean        sd    hdi_3%   hdi_97%  mcse_mean       mcse_sd  \
# a[0]       0.000152  0.000038  0.000078  0.000221   0.000001  8.000000e-07
# a[1]       0.000043  0.000037 -0.000029  0.000110   0.000001  8.000000e-07
# a ratio    0.000109  0.000053  0.000002  0.000202   0.000002  1.100000e-06
# m hier[0]  0.499857  0.075481  0.353634  0.639501   0.002301  1.629600e-03
# m hier[1]  0.740583  0.074184  0.596642  0.873610   0.002066  1.461200e-03
# m sig[0]   0.053145  0.011153  0.033803  0.073898   0.000283  2.005000e-04
# m sig[1]   0.052789  0.012046  0.029750  0.073944   0.000326  2.304000e-04
#
#               ess_mean       ess_sd     ess_bulk     ess_tail     r_hat
# a[0]       1035.693820  1035.693820  1043.530573  1757.010702  1.001607
# a[1]       1238.414477  1215.025198  1239.516806  1616.887484  1.004624
# a ratio    1131.232753  1131.232753  1131.156338  1635.202472  1.002987
# m hier[0]  1075.998287  1073.236685  1080.475108  1805.523820  1.001108
# m hier[1]  1289.283679  1289.283679  1290.307945  1658.932019  1.005436
# m sig[0]   1548.255710  1548.255710  1565.447353  2644.180670  1.000705
# m sig[1]   1366.876399  1366.876399  1355.199780  2232.475233  1.003458

# %%
 
plt.figure(figsize=(8,8))
matplotlib.rcParams.update({'font.size': 18,"axes.labelsize": 20})

plt.errorbar(x=df_cleaned['T eq']/(0.25**0.25),y=summary_hier_ratio_2['mean'],yerr=summary_hier_ratio_2['sd'],linestyle='None',color='k')
plt.scatter(x=df_cleaned['T eq']/(0.25**0.25),y=summary_hier_ratio_2['mean'],color='k',s=60,label='Hierarchical')
plt.errorbar(x=df_cleaned['T eq']/(0.25**0.25),y=df_cleaned['m'],yerr=df_cleaned['m err'],linestyle='None',color='maroon',alpha=0.5)
plt.scatter(x=df_cleaned['T eq']/(0.25**0.25),y=df_cleaned['m'],color='maroon',s=60,alpha=0.5,label='Separate')
plt.axhline((2/3)**0.25,color='gray')
plt.axhline(0.5**0.25,color='gray',linestyle='dashed')
plt.axhline(0.25**0.25,color='gray',linestyle='dotted')
plt.ylabel(r'$T_{\rm day}/T_{0}$')
plt.xlabel(r'$T_{0}$')
plt.ylim(0.18,1.1)
plt.legend(loc=4)
#plt.savefig('Garhart_Hier_2channel.pdf',bbox_inches='tight')
